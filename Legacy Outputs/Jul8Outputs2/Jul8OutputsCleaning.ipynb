# %%
import pandas as pd
import numpy as np

# %%
errors = pd.read_csv("errors.csv")
errors
# Out:
#         SHORTCODE          CLUB               ERROR
# 0      mDxJ5LAaQG   wetrepublic  <class 'KeyError'>
# 1     BIX07elhY0U  cavesduroyST  <class 'KeyError'>
# 2     BE0u1o_HdNv         rudas  <class 'KeyError'>
# 3     BdL7ulDDiKx   oxfordsc_sd  <class 'KeyError'>
# 4      6sX7jYAaTp   wetrepublic  <class 'KeyError'>
# 5      owgE5BgaTl   wetrepublic  <class 'KeyError'>
# 6      -Kpxdnq0Bk      templeSF  <class 'KeyError'>
# 7      mggLjwgaa9   wetrepublic  <class 'KeyError'>
# 8     BDkiCqQHdGY         rudas  <class 'KeyError'>
# 9     BeD2QJmj4iM   wetrepublic  <class 'KeyError'>
# 10    BhE1OMwDCls   wetrepublic  <class 'KeyError'>
# 11    BPZApmjDYW3      templeSF  <class 'KeyError'>
# 12    BYOqF10FArk       prsymCH  <class 'KeyError'>
# 13     tInunwgadc   wetrepublic  <class 'KeyError'>
# 14    BIv5WeFAVu_      templeSF  <class 'KeyError'>
# 15     pMqN8fAacZ   wetrepublic  <class 'KeyError'>
# 16     oJ6bxnAaVL   wetrepublic  <class 'KeyError'>
# 17    BBIf9uUK0EU      templeSF  <class 'KeyError'>
# 18    BXGYO4OARED       grandSF  <class 'KeyError'>
# 19    BTW8CFjDiMh   wetrepublic  <class 'KeyError'>
# 20    BQGwAy0FwiO   wetrepublic  <class 'KeyError'>
# 21    BQ6RkOFlqSO  cavesduroyST  <class 'KeyError'>
# 22     lStL3UAaXq   wetrepublic  <class 'KeyError'>
# 23    BXGezXnFqWb      templeSF  <class 'KeyError'>
# 24    BN7hcPgDrSd      templeSF  <class 'KeyError'>
# 25    BhZ0ECIBPfr   grandBoston  <class 'KeyError'>
# 26    BTo5LJjDv5N   wetrepublic  <class 'KeyError'>
# 27    BDkicBGHdG7         rudas  <class 'KeyError'>
# 28    BGxFT8AgaV3   wetrepublic  <class 'KeyError'>
# 29    BIOGdNSgucW       grandSF  <class 'KeyError'>
# ...           ...           ...                 ...
# 2351  BPGK-4zjp7b      templeSF  <class 'KeyError'>
# 2352  BYoHQ3bDydg   wetrepublic  <class 'KeyError'>
# 2353  BdeJP6-HCnx      templeSF  <class 'KeyError'>
# 2354  BTDFYeDlCza       prsymCH  <class 'KeyError'>
# 2355   3Rgc6ZAaXU   wetrepublic  <class 'KeyError'>
# 2356  BIVd13UgYUs         rudas  <class 'KeyError'>
# 2357  BFGl753HdJv         rudas  <class 'KeyError'>
# 2358  BZrgpP5H9Xy  cavesduroyST  <class 'KeyError'>
# 2359   olxQ_3AaVd   wetrepublic  <class 'KeyError'>
# 2360   oSU9QDgaZB   wetrepublic  <class 'KeyError'>
# 2361  Bixa3bYlalU       prsymCH  <class 'KeyError'>
# 2362  BCmQcUDK0OY      templeSF  <class 'KeyError'>
# 2363  BL-FBWcD2eM      templeSF  <class 'KeyError'>
# 2364  BGZqeWngacq   wetrepublic  <class 'KeyError'>
# 2365   daal81AaXI   wetrepublic  <class 'KeyError'>
# 2366  BWOB2KnjJGW   wetrepublic  <class 'KeyError'>
# 2367   4EH9d-gafC   wetrepublic  <class 'KeyError'>
# 2368  BTdXzVdlFrq       prsymCH  <class 'KeyError'>
# 2369   544F38gaa5   wetrepublic  <class 'KeyError'>
# 2370   d-cJ40AafL   wetrepublic  <class 'KeyError'>
# 2371   OfOsO5AaRZ   wetrepublic  <class 'KeyError'>
# 2372  BaP4A6cFojZ       prsymCH  <class 'KeyError'>
# 2373  BW3olYUlulg       prsymCH  <class 'KeyError'>
# 2374   pbuibggafW   wetrepublic  <class 'KeyError'>
# 2375  BThU7NfDOUO   wetrepublic  <class 'KeyError'>
# 2376  BFGmDPeHdJ9         rudas  <class 'KeyError'>
# 2377  Bd4j-1TFkjo       prsymCH  <class 'KeyError'>
# 2378  BcNz_AKFzIX       prsymCH  <class 'KeyError'>
# 2379  Bc-nI-pnyP9      templeSF  <class 'KeyError'>
# 2380  Bdl6l7qHCle      templeSF  <class 'KeyError'>
#
# [2381 rows x 3 columns]

# %%
import os
clubs = errors["CLUB"].value_counts().index
for club in clubs: 
    club_errors = errors[errors["CLUB"] == club]
    club_errors = club_errors["SHORTCODE"]
    file = open("errors/" + club + ".txt", "w")
    file.write("[")
    for error in club_errors:
        file.write("\"" + error + "\",")
    file.write("]")
    file.close()
