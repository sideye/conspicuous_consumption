# %%
import pandas as pd
import numpy as np

# %%
errors = pd.read_csv("Jul5Outputs/errors.csv")

# %%
errors
# Out:
#         SHORTCODE          CLUB               ERROR
# 0     BV0gm5ulsgs       prsymCH  <class 'KeyError'>
# 1     BGkGcLyK0Mv      templeSF  <class 'KeyError'>
# 2      2obCKygaZG   wetrepublic  <class 'KeyError'>
# 3     BXJa45NFeUu       prsymCH  <class 'KeyError'>
# 4     BUpIp5jFh5q       prsymCH  <class 'KeyError'>
# 5      I5KElJgaeG   wetrepublic  <class 'KeyError'>
# 6      60zgQ_q0OJ      templeSF  <class 'KeyError'>
# 7     BPf-IgOBj9U   wetrepublic  <class 'KeyError'>
# 8      11Nzmngae6   wetrepublic  <class 'KeyError'>
# 9      wkZHlwq0JC      templeSF  <class 'KeyError'>
# 10    BFshAoeK0DK      templeSF  <class 'KeyError'>
# 11    BZg8pN5lOJQ       prsymCH  <class 'KeyError'>
# 12    BIYp8PjghvM       grandSF  <class 'KeyError'>
# 13    BODVCk5j2W2       prsymCH  <class 'KeyError'>
# 14    BRi35qyjxQc   wetrepublic  <class 'KeyError'>
# 15    BRg5c1tj_P5      templeSF  <class 'KeyError'>
# 16    BUkNaaplBld       prsymCH  <class 'KeyError'>
# ...

# %%
prysmCH = errors[errors["CLUB"] == "prsymCH"]
errors_prsymCH = prysmCH["SHORTCODE"]

# %%
import os
file = open("prysmCH.txt", "w")
for error in errors_prsymCH:
    file.write("\"" + error + "\",")
file.close()
