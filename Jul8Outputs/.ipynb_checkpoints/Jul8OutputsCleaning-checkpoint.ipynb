# %%
import pandas as pd
import numpy as np

# %%
errors = pd.read_csv("errors.csv")
errors
# Out:
#         SHORTCODE          CLUB               ERROR
# 0     BJRlYmjgiTq      templeSF  <class 'KeyError'>
# 1     Ba9iUYWhZCP         rudas  <class 'KeyError'>
# 2      rQWCScgab4   wetrepublic  <class 'KeyError'>
# 3     BShsTokAPDU      templeSF  <class 'KeyError'>
# 4     BX8V2N-j5sT   wetrepublic  <class 'KeyError'>
# 5     Bbh_AuzD__d   wetrepublic  <class 'KeyError'>
# 6     BLMbh7sBYJ8  cavesduroyST  <class 'KeyError'>
# 7     BDkimM0HdHK         rudas  <class 'KeyError'>
# 8     BNFZgtpjITW       prsymCH  <class 'KeyError'>
# 9     BNM7FKMhAmO  cavesduroyST  <class 'KeyError'>
# 10     riV1QlAaZ-   wetrepublic  <class 'KeyError'>
# 11    BUFQT5ED_35   wetrepublic  <class 'KeyError'>
# 12    BJ5sTFQBvRe   wetrepublic  <class 'KeyError'>
# 13     X0fWrnAaQ6   wetrepublic  <class 'KeyError'>
# 14    BVwWL-sFhZH       prsymCH  <class 'KeyError'>
# 15    BXJa45NFeUu       prsymCH  <class 'KeyError'>
# 16    BSbn2Krl_O-       prsymCH  <class 'KeyError'>
# 17    BIlCQX4hd1-  cavesduroyST  <class 'KeyError'>
# 18    BE-8t_eHdNI         rudas  <class 'KeyError'>
# 19     qMwmjugad7   wetrepublic  <class 'KeyError'>
# 20    BVXjarkDp_X   wetrepublic  <class 'KeyError'>
# 21    BVYbilpFS2y       prsymCH  <class 'KeyError'>
# 22    BDaLTkBndAO         rudas  <class 'KeyError'>
# 23     5NJ4AFgaYs   wetrepublic  <class 'KeyError'>
# 24    BD1RDTpAacN   wetrepublic  <class 'KeyError'>
# 25     s-aM8pAadX   wetrepublic  <class 'KeyError'>
# 26    BR40NG4gcUt   oxfordsc_sd  <class 'KeyError'>
# 27    BBWGVRJAadb   wetrepublic  <class 'KeyError'>
# 28    BUm-Zkvlllc       prsymCH  <class 'KeyError'>
# 29    BILSEqkAbIT       grandSF  <class 'KeyError'>
# ...           ...           ...                 ...
# 3408  BJ7nAa-AsaM         rudas  <class 'KeyError'>
# 3409  BcBIHMXlljY       prsymCH  <class 'KeyError'>
# 3410  BQoZU_LlZAY       prsymCH  <class 'KeyError'>
# 3411   2NPkH2gaZL   wetrepublic  <class 'KeyError'>
# 3412  BVYG9u_glaz       grandSF  <class 'KeyError'>
# 3413  BInqcUUgeln         rudas  <class 'KeyError'>
# 3414  BZmL4cwBKmr       grandSF  <class 'KeyError'>
# 3415  BDbhN0NgaRY   wetrepublic  <class 'KeyError'>
# 3416  BJDnmAdgRXe         rudas  <class 'KeyError'>
# 3417  BOQC6AUDmhb      templeSF  <class 'KeyError'>
# 3418  BFt7DIqHdF3         rudas  <class 'KeyError'>
# 3419   tGEj7wgaXE   wetrepublic  <class 'KeyError'>
# 3420  BJoH5S5AgYT         rudas  <class 'KeyError'>
# 3421  Be4CYAvBqj9       grandSF  <class 'KeyError'>
# 3422   r5mgmjAadh   wetrepublic  <class 'KeyError'>
# 3423   nEj3CwgabG   wetrepublic  <class 'KeyError'>
# 3424  BFGmDPeHdJ9         rudas  <class 'KeyError'>
# 3425  BDuI7buq0Jg      templeSF  <class 'KeyError'>
# 3426  BA59IfUK0DH      templeSF  <class 'KeyError'>
# 3427   4Cv3zhgaRv   wetrepublic  <class 'KeyError'>
# 3428  BEauJVoHdBj         rudas  <class 'KeyError'>
# 3429   J-Zgc9gaWE   wetrepublic  <class 'KeyError'>
# 3430  BVU_DI3D_ye   wetrepublic  <class 'KeyError'>
# 3431  Bc5O88Nlm7q       prsymCH  <class 'KeyError'>
# 3432  BGziGSJq0Kd      templeSF  <class 'KeyError'>
# 3433   8Q5s_KgaZi   wetrepublic  <class 'KeyError'>
# 3434  BTE2PGDlikU       prsymCH  <class 'KeyError'>
# 3435  BTww5CXlX3J       prsymCH  <class 'KeyError'>
# 3436   q5FWBXAafb   wetrepublic  <class 'KeyError'>
# 3437  BFxe8kFK0Ig      templeSF  <class 'KeyError'>
#
# [3438 rows x 3 columns]

# %%
import os
clubs = errors["CLUB"].value_counts().index
for club in clubs: 
    club_errors = errors[errors["CLUB"] == club]
    club_errors = club_errors["SHORTCODE"]
    file = open("errors/" + club + ".txt", "w")
    file.write("[")
    for error in club_errors:
        file.write("\"" + error + "\",")
    file.write("]")
    file.close()
