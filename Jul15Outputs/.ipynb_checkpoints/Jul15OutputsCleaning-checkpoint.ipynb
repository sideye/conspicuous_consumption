# %%
import pandas as pd
import numpy as np

# %%
errors = pd.read_csv("errors.csv")
errors
# Out:
#         SHORTCODE         CLUB                                   ERROR
# 0     BAvrpgOK0P2     templeSF                      <class 'KeyError'>
# 1     BVcsg2vDigm  wetrepublic                      <class 'KeyError'>
# 2     BFGmDPeHdJ9        rudas                      <class 'KeyError'>
# 3      -4g8KDq0L5     templeSF                      <class 'KeyError'>
# 4     BKQuMU6gEUc        rudas                      <class 'KeyError'>
# 5      qF_FzjgaWC  wetrepublic                      <class 'KeyError'>
# 6     BDBJ_XrndI0        rudas                      <class 'KeyError'>
# 7      sTPMTOgaUl  wetrepublic                      <class 'KeyError'>
# 8     Bc28GfAHSub     templeSF                      <class 'KeyError'>
# 9     BMNrs2XDyj4      prsymCH                      <class 'KeyError'>
# 10    BLrTye9j85P      prsymCH                      <class 'KeyError'>
# 11     lLLWDYgacu  wetrepublic                      <class 'KeyError'>
# 12    BGQeK71q0JV     templeSF                      <class 'KeyError'>
# 13    BbIMpcvBnrq      grandSF                      <class 'KeyError'>
# 14    BYRpc_qFHhS      prsymCH                      <class 'KeyError'>
# 15    BfBw7kZHc2O     templeSF                      <class 'KeyError'>
# 16    BVkwEMNlbXi      prsymCH                      <class 'KeyError'>
# 17     qSOr6GAaR1  wetrepublic                      <class 'KeyError'>
# 18    BiFJFKYhVuY  grandBoston  <class 'json.decoder.JSONDecodeError'>
# 19    BSpT_JYg41D      grandSF                      <class 'KeyError'>
# 20    BgUPuWQje91  wetrepublic                      <class 'KeyError'>
# 21     XFlGZOgaUm  wetrepublic                      <class 'KeyError'>
# 22     8y5tTTAaeP  wetrepublic                      <class 'KeyError'>
# 23     42dEYJK0HT     templeSF                      <class 'KeyError'>
# 24    Bb8STbHHpS1     templeSF                      <class 'KeyError'>
# 25    BUIzT5TgIb6     templeSF                      <class 'KeyError'>
# 26    BFGmsqTHdLY        rudas                      <class 'KeyError'>
# 27     3AeaTBq0Bi     templeSF                      <class 'KeyError'>
# 28    BRbNTMqlt5Q      prsymCH                      <class 'KeyError'>
# 29    Bdk8cxZjqG7  wetrepublic                      <class 'KeyError'>
# ...           ...          ...                                     ...
# 1038  BIGKw8kDGTx      prsymCH                      <class 'KeyError'>
# 1039   0ynbeDgacF  wetrepublic                      <class 'KeyError'>
# 1040   b99U0OgaeT  wetrepublic                      <class 'KeyError'>
# 1041  BK6teNtDR67      prsymCH                      <class 'KeyError'>
# 1042  BfjK3QbnqVY     templeSF                      <class 'KeyError'>
# 1043  BF6vXQKq0C0     templeSF                      <class 'KeyError'>
# 1044  BcabnUEBPkf      grandSF                      <class 'KeyError'>
# 1045   n54zyxAadp  wetrepublic                      <class 'KeyError'>
# 1046  BF1IxM5ndPJ        rudas                      <class 'KeyError'>
# 1047  BKTQT8qjLOu      prsymCH                      <class 'KeyError'>
# 1048  BaFnJ8-B6N0      grandSF                      <class 'KeyError'>
# 1049   qNKORtgaQF  wetrepublic                      <class 'KeyError'>
# 1050  BQo2Abng9QF     templeSF                      <class 'KeyError'>
# 1051  Bd500chni1d     templeSF                      <class 'KeyError'>
# 1052   ccdLbKgaQH  wetrepublic                      <class 'KeyError'>
# 1053   sfbHIjgaUp  wetrepublic                      <class 'KeyError'>
# 1054  BVYLPm4g2mX  oxfordsc_sd                      <class 'KeyError'>
# 1055  BbXxNV3ntC5     templeSF                      <class 'KeyError'>
# 1056   qzRlUWgaSH  wetrepublic                      <class 'KeyError'>
# 1057  BUCtCVBAOj9      grandSF                      <class 'KeyError'>
# 1058   9WpmsoK0Eb     templeSF                      <class 'KeyError'>
# 1059   4SSXoJAaUN  wetrepublic                      <class 'KeyError'>
# 1060  BJqPhVKh8bI  wetrepublic                      <class 'KeyError'>
# 1061  BJmys7cABch        rudas                      <class 'KeyError'>
# 1062  BU6I9CeFEQn      prsymCH                      <class 'KeyError'>
# 1063  BcsSQE9l_YB      prsymCH                      <class 'KeyError'>
# 1064  BNr1kXRBpnJ  wetrepublic                      <class 'KeyError'>
# 1065  BR40NG4gcUt  oxfordsc_sd                      <class 'KeyError'>
# 1066  BR7HBJVADYI     templeSF                      <class 'KeyError'>
# 1067  BiXJ8VFBeOc  grandBoston  <class 'json.decoder.JSONDecodeError'>
#
# [1068 rows x 3 columns]

# %%
import os
clubs = errors["CLUB"].value_counts().index
for club in clubs: 
    club_errors = errors[errors["CLUB"] == club]
    club_errors = club_errors["SHORTCODE"]
    file = open("errors/" + club + ".txt", "w")
    file.write("shortcodes_"+ club + " = [")
    for error in club_errors:
        file.write("\"" + error + "\",")
    file.write("]")
    file.close()
